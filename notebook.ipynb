# %% [markdown]
# <a href="https://colab.research.google.com/github/RomainCoulon/consensusGen/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ConsensusGen - User guide

# %%
pip install consensusGen==2.5
# Out:
# ...
#   Using cached consensusGen-2.5-py3-none-any.whl (6.4 kB)
# ...
#   Attempting uninstall: consensusGen
#     Found existing installation: consensusGen 2.4
#     Uninstalling consensusGen-2.4:
#       Successfully uninstalled consensusGen-2.4
# ...

# %%
import consensusgen as csg

# %% [markdown]
# ## Input data

# %%
l = ["A", "B", "C", "D", "E", "F", "G"]
x = [10.1, 11, 14, 10, 10.5, 9.8, 5.1]
u = [1,    1, 1,  2, 1,    1.5, 3]

# %% [markdown]
# ## Estimate the reference value

# %%
result = csg.consensusGen.consensusGen(x, u)
# Out:
# The sibling rate at generation 1 is 63.15% (size: 6312).
# The sibling rate at generation 2 is 100.00% (size: 6312).
# The sibling rate at generation 3 is 100.00% (size: 6312).

# %% [markdown]
# ## Display the result

# %%
csg.consensusGen.displayResult(x, u, result, lab=l)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# The consensus value is 10.3 ± 0.63 (k=1)
# The degrees of equivalence are:
# 	 A: -0.2 ± 2 (k=2)
# 	 B: 0.7 ± 2.1 (k=2)
# 	 C: 3.7 ± 2.3 (k=2)
# 	 D: -0.3 ± 3.4 (k=2)
# 	 E: 0.2 ± 2 (k=2)
# 	 F: -0.5 ± 2.7 (k=2)
# 	 G: -5.2 ± 5.7 (k=2)
