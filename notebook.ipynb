# %% [markdown]
# <a href="https://colab.research.google.com/github/RomainCoulon/consensusGen/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ConsensusGen - User guide

# %%
pip install consensusGen --upgrade
# Out:
# Requirement already satisfied: consensusGen in /usr/local/lib/python3.10/dist-packages (1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from consensusGen) (1.25.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from consensusGen) (4.66.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from consensusGen) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->consensusGen) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->consensusGen) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->consensusGen) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->consensusGen) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->consensusGen) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->consensusGen) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->consensusGen) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->consensusGen) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->consensusGen) (1.16.0)

# %%
import consensusgen as csg

# %% [markdown]
# ## Input data

# %%
l = ["A","B","C","D","E", "F"]
x = [10, 13, 11, 12, 10.5, 17]
u = [1 , 2 , 1 , 1 , 0.5 , 1]

# %% [markdown]
# ## Estimate the reference value

# %%
result = csg.consensusGen.consensusGen(x, u)

# %% [markdown]
# ## Display the result

# %%
csg.consensusGen.displayResult(x, u, result, lab=l)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# The consensus value is 11.38 ± 0.68 (k=1)
# The degrees of equivalence are:
# 	 A: -1.4 ± 2.1 (k=2)
# 	 B: 1.6 ± 3.4 (k=2)
# 	 C: -0.38 ± 2 (k=2)
# 	 D: 0.62 ± 2.1 (k=2)
# 	 E: -0.88 ± 1.6 (k=2)
# 	 F: 5.6 ± 2.4 (k=2)
